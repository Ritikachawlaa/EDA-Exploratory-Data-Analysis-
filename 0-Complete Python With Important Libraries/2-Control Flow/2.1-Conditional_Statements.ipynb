# %% [markdown]
# ## Conditional Statements (if, elif, else)
#
# 1. Introduction
# 2. if
# 3. else
# 4. elif
# 5. Nested Conditional Statements
# 6. Examples

# %%
## if statement
age=20

if age>=18:
    print("You are allowed to vote in the elections")
# Out:
# You are allowed to vote in the elections

# %%
## else 
## The else statement executes a block of code if the condition in the if statement is False

age=16

if age>=18:
    print("You are eligible for voting")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
## elif
## The elif statement allows you to check multiple conditions. It stands for "else if"

age=17

if age<13:
    print("You are a child")
elif age<18:
    print("You are a teenager")
else:
    print("You are an adult")
# Out:
# You are a teenager

# %%
## Nested Conditional Statements
## You can place one or more if, elif or else statement inside another if, elif or else statement to create nested conditional statemnts.

## number even ,odd, negative

num=int(input("Enter the number:"))

if num>0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")
else:
    print("The number is zero or negative")

# %%
## Examples

## Determine if a year is a leap year using nested condtional statement

year = int(input("Enter the year:"))

if(year % 4 == 0):
    if (year % 100 == 0):
        if ( year % 400 == 0):
            print(year,"It is a leap year")
        else:
            print(year,"is not a leap year")
    else:
        print(year,"year is a leap year")
else:
    print(year,"It is not a leap year")
# Out:
# 2024 year is a leap year

# %%
## Simple Calculator program 

num1 = float(input("Enter your first number: "))
num2 = float(input("Enter your second number: "))
op= input("Enter your operation(+, -,*,/): ")

if (op == "+"):
    result = num1 + num2
elif (op == "-"):
    result = num1 - num2
elif(op == "*"):
    result = num1 * num2
elif(op == "/"):
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error!Divison by zero."
else:
    result = "Invalid operation"
print("Result", result)
# Out:
# Result 0.8571428571428571

# %%
### Determine the ticket price based on age and student status

is_student = input("Are you a student(Yes/No): ")
age= int(input("Enter your age: "))

if(is_student == "Yes"):
    if (age < 5):
        price = "Free"
    elif (age <= 12):
        price = "10"
    elif (age <= 17):
        price = "12"
    elif (age <= 25):
        price = "15"
    elif (age <= 40):
        price = "25"
    else:
        price = "450"


print("Ticket Price:", price)
# Out:
# Ticket Price: 12
