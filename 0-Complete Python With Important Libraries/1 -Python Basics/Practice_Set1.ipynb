# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
str="Hello, World!"
print(str)
# Out:
# Hello, World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
str = input("Enter your name : ")
print(str)
# Out:
# Ritika

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num1 = int(input("Enter your number : "))
if num1>0:
    print("positive")
elif num1<0:
    print("negative")
else :
    print("THe number is zero")
# Out:
# THe number is zero

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = int(input("Enter your first number : "))
num2 = int(input("Enter your second number : "))
num3 = int(input("Enter your third number : "))
if(num1>num2 & num1>num3):
    print("Num1 is greatest which is ", num1)
elif(num2>num3 & num2>num1):
    print("Num2 is greatest which is ", num2)
else :
    print("Num3 is greatest which is ", num3)
# Out:
# Num1 is greatest which is  -5

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
def factorial(n):
    if(n==0):
        return 1
    else:
        return n * factorial(n-1)
    
num=int(input("Enter a number: "))
print(factorial(num))
# Out:
# 6

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
name="Ritika"
age=21
height=5.7
is_student=True
print(name, type(name))
print(age, type(age))
print(height, type(height))
print(is_student, type(is_student))
# Out:
# Ritika <class 'str'>
# 21 <class 'int'>
# 5.7 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a=5
b=10
a=a+b # a= 15
b=a-b # b= 5
a=a-b # a= 10
print(a,b)
# Out:
# 10 5

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celsius=float(input("Enter the temperature :"))
fahrenheit = (celsius *9/5 + 32)
print("temperature in fahrenheit is ", fahrenheit)
# Out:
# temperature in fahrenheit is  73.4

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1="Ritika"
str2=" Chawla"
result=str1+str2
print(result)
# Out:
# Ritika Chawla

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
height = input("Enter your height: ")
type(height)
# Out:
# str

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
## Simple Calculator
num1= float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

sum = num1 + num2
difference = num1 - num2
multiplication = num1 * num2
division = num1 / num2

print("Sum is ", sum)
print("Difference is ", difference)
print("Product is ", multiplication)
print("Quotient is ", division)
# Out:
# Sum is  12.0
# Difference is  -2.0
# Product is  35.0
# Quotient is  0.7142857142857143

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
num1=6
num2=5
print(num1==num2)
print(num1!=num2)
print(num1<num2)
print(num1>num2)
# Out:
# False
# True
# False
# True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
#OR
X=True
Y=False
result = X or Y
print(result)

#Not
x=False
print(not X)

# And
X=True
Y=False
result = X and Y
print(result)
# Out:
# True
# False
# False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = int(input("Enter your number"))
square = num * num
print(square)
# Out:
# 81

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter your number"))
if(num % 2 == 0):
    print("even")
else:
    print("odd")
# Out:
# even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n = int(input("Enter your number : "))
sum = (n * (n+1)) // 2
print(sum)
# Out:
# 28

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter the year : "))
if( year % 4 == 0 & year % 100 != 0) or (year % 400 == 0): # input = 2024
    print("leap year")
else:
    print("not a leap year")
# Out:
# not a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
string = str(input("Enter your string : ")) # input = hello
reversed_string = string[::-1]
print(reversed_string)
# Out:
# olleh

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
string = str(input("Enter your string : ")) # input = 121,rotator,delhi
if string == string[::-1]:
    print(string," is a palindrome")
else:
    print( string,"is not a palindrome")
# Out:
# rotator  is a palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
list = [int(x) for x in input("Enter your list of numbers separated by space: ").split()]
list.sort()
print(list)
# Out:
# [2, 3, 4, 5, 6, 7, 9]
