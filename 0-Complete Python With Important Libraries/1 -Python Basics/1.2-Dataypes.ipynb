# %% [markdown]
# ## DataTypes
# 1. Introduction
# 2. Basic Data Types -
#     Integer|
#     Float|
#     String|
#     Booleans
# 3. Advanced Data Types
#     Lists|
#     Tuples|
#     Sets|
#     Dictionaries
# 4. Type Conversion
# 5. Examples

# %%
## Integer Example
age=35
print(age,type(age))
# Out:
# 35 <class 'int'>

# %%
## Floating point Example
height=5.11
print(height,type(height))
# Out:
# 5.11 <class 'float'>

# %%
## String Example
name="krish"
print(name, type(name))
# Out:
# krish <class 'str'>

# %%
## Boolean Example
# One Way
is_student=True
print(is_student,type(is_student))
# Out:
# True <class 'bool'>

# %%
# Another Way
a=10
b=10

a==b
print(a==b,type(a==b))
# Out:
# True <class 'bool'>

# %%
## Common Errors

result="Hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 ## Common Errors
# ----> 3 result="Hello" + 5
#       4 print(result)
#       6 result="Hello" + str(5) # typecasted
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Error solved

result="Hello " + str(5) # typecasted 
print(result)
# Out:
# Hello 5
