# %% [markdown]
#  ## Syntax and Semantics in Python
#
#   1. Single line and multiline comments
#   2. Basic Syntax Rules
#   3. Examples

# %%
##  THIS IS A SINGLE LINE COMMENT

print("Hello World")
# Out:
# Hello World

# %%
'''
this is a multiline comment
'''
## but this doesnot work in ipynb file
# Out:
# '\nthis is a multiline comment\n'

# %%
## Basic rule of python
## Case sensitivity - Python is case Sensitive

# Example 
name="Krish"
Name = "Naik"

print(name)
print(Name)
# Out:
# Krish
# Naik

# %%
# Indentation 
## Python uses identation to define blocks of code. Consistent use of spaces(commonly 4) or a tab is required
# Example

age=32
if age>30:
    print(age)

print(age)
# Out:
# 32
# 32

# %%
## Line continuation 
# Use a backslash(\) to continue a statement to the next line

total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiple Statements on a single line 

x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## Understanding Semantics in Python 
# Variable assignment 
age=32 ## age is an integer
name="krish" ## name is string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inferences 
variable=10
print(type(variable))
variable="krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Name Error 
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 ## Name Error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## Code examples of indention
if True:
    print("Correct indentation")
    if False:
        print("This will not print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct indentation
# This will print
# Outside the if block
