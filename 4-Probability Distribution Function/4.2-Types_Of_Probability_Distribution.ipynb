# %% [markdown]
# ## Types of Probability Distribution
#
# **1. Bernoulli Distribution -**
#     Outcomes are completely binary (pmf) , discrete random variable
#
# **2. Binomial Distribution -**
#     Discrete random variable (pmf)
#
# **3. Normal / Gaussian Distribution -**
#     Continous random variable (pdf) - bell curve
#
# **4. Poission Distribution -**
#    Discrete random variable (pmf)
#
# **5. Log-Normal Distribution -**
#    Continous random variable (pdf)
#
# **6. Uniform Distribution -**
#     Discrete random variable (pmf)

# %% [markdown]
# DATASET - Houseprice prediction dataset
#
# - size of the house (continous random variable {pdf})
# - no.of rooms (discrete random variable {pmf})
# - location
# - floor (discrete random variable {pmf})
# - sea side (discrete random variable {pmf} {0,1})
# - price (discrete random variable {pmf})
