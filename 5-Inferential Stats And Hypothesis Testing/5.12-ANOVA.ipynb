# %% [markdown]
# ## Analysis of Variance (ANOVA)
#
# **ANOVA** is a statistical method used to compare the means of 2 or more groups.

# %% [markdown]
# ### Components -
#
# 1. Factors (Variable)
# 2. Levels
#
# Eg- Medicine (Factor)
#     5mg, 10 mg, 15mg (Dosage - levels)
#
# Eg- Mode of Pyament (Factor)
#     GPay, PhonePe,IMPS,NEFT (levels)
