# %% [markdown]
# ## Statistics
#
# DEFINITION - Statistics is the science of collecting,organizing, and anayzing data.

# %% [markdown]
# DATA - Facts or peices of information
#
# eg1- Weights of students in the class
# {60kg,50kg,45kg,30kg}
#
# eg2- IQ of student in class
# {100,90,95,98,...}

# %% [markdown]
# HOUSEPRICE DATASET -
#
# City        1-Area            2-No. of rooms         3-Price
#
# Banglore       1000                2                 45lakhs
# Mumbai       1250                 2.5                50lakhs
# New York       -                   -                    -
#
# Data Scientist - will predict the price of the house in another city.acoording to dataset provided.
#
# Data Analyst - will create report,visualization which will help them in taking decision.for eg- where to start new project for a builder.

# %% [markdown]
# ##### Important Application of Statistics
#
# 1. Data Exploration and Summarize
# 2. Model Building and Validation
# 3. Statistical Analysis - It is done on sample data to make   conclusion about population.
# 4. Hypothesis Testing
# 5. Optimization and Efficiency
# 6. Reporting
